# %%
import pandas as pd
import seaborn as sns
import datetime as date

# %%
df = pd.read_csv("https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/housing.csv")

# %%
df["Date New"] = pd.to_datetime(df['date'], 
                        format="%Y-%m-%dT%H:%M:%S.%f")
df.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  1565930130  20141104T000000         4       3.25         3760      4675
# 1  3279000420  20150115T000000         3       1.75         1460      7800
# 2   194000575  20141014T000000         4       1.00         1340      5800
# 3  2115510160  20141208T000000         3       1.75         1440      8050
# 4  7522500005  20140815T000000         2       1.50         1780      4750
#
#    floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 0     2.0           0     0          3  ...           1020      2007
# 1     1.0           0     0          2  ...            420      1979
# 2     1.5           0     2          3  ...              0      1914
# 3     1.0           0     0          3  ...              0      1985
# 4     1.0           0     0          4  ...            700      1947
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
# Price ~ Year Built color = # of floors

sns.scatterplot(data=df, x="yr_built", y="price", hue="floors")
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
sns.scatterplot(data=df, x="yr_built", y="price", hue="view")
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
sns.histplot(data=df, x="floors")

# %%
#histogram by number of floors

sns.histplot(data=df, x="view")
# Out:
# <AxesSubplot:xlabel='view', ylabel='Count'>

# %%
sns.histplot(data=df, x="Date New")
# Out:
# <AxesSubplot:xlabel='Date New', ylabel='Count'>

# %%
sns.boxplot(data=df, x="bedrooms")
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
from numpy import average



sns.lineplot(data=df, x="yr_built", y="price")
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
sns.lineplot(data=df, x="Date New", y="price")
# Out:
# <AxesSubplot:xlabel='Date New', ylabel='price'>

# %%
import matplotlib.pyplot as plt
# plt.scatter(x=df['long'], y=df['lat'], hue='price')
# plt.show()


sns.scatterplot(data=df, x='long', y='lat', hue='price', size="price",
    sizes=(1, 200))
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.scatterplot(data=df, x='long', y='lat', hue='sqft_lot', size="sqft_lot",
    sizes=(.25, 200))
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qy/tb7_9f7d5bn161y_1qw30_c00000gn/T/ipykernel_4763/1472378890.py in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
